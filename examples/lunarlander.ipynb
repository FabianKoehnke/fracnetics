# %% [markdown]
# # Lunar Lander Notebook
# This notebook demonstrates GNP landing a spacecraft.

# %% [markdown]
# # Small Tutorial Using Fracnetics
#
# ## Summary 🔭
#
# This notebook demonstrates how to use the **Fracnetics** library to solve the CartPole environment problem from Gymnasium (fork from OpenAI Gym).
#
# Fractnetics is a Python library for **Genetic Network Programming (GNP)** enhanced with fractal geometry, which means it a subfield of Evolutionary Algorithms.
#
# ## Lunar Lander
#
# The Lunar Lander problem is a classic reinforcement learning task where an agent must safely land a spacecraft on a designated landing pad. The lander can control its main and side thrusters to adjust its position and velocity. The goal is to land softly and upright, while avoiding crashes or going out of bounds. Rewards are given for touching down gently and penalties for collisions, fuel use, or leaving the landing area. This problem tests an agent’s ability to balance precision control with strategic planning under continuous dynamics.
#
# ![Beschreibung](https://gymnasium.farama.org/_images/lunar_lander.gif)
#
# ## Evolutionary Aglortihms 🧬
#
# Evolutionary Algorithms are a family of optimization techniques inspired by the process of natural evolution. They work by maintaining a **population** of candidate solutions, which evolve over time through operations such as **selection, mutation, and crossover**. The idea is to iteratively improve solutions by mimicking survival of the fittest, where better solutions are more likely to be chosen and combined to form new ones. EAs are especially useful for solving complex, nonlinear, and high-dimensional problems where traditional optimization methods may fail.
#
# ## Genetic Network Programming 🦾
#
# Genetic Network Programming is a branch of evolutionary computation that represents solutions as **networks** of nodes rather than as linear strings (like in Genetic Algorithms). Each node corresponds to a function, decision, or action, and the network’s structure allows for recurrent flows of control. This enables GNP to model adaptive, flexible, and memory-dependent behaviors. It has been applied successfully in areas such as robotics, decision-making systems, and dynamic optimization tasks.
#
# ## Next 🔥
# In this tutorial we will initialize a population, train it, validate it, and finally record a run.
#
# Checkout Fracnetics and Gymnasium here:
#
# - Fracnetics: https://github.com/FabianKoehnke/fracnetics
# - Gymnasium: https://gymnasium.farama.org/

# %% [markdown]
# ## Install and Load Packages

# %%
# !pip install --upgrade fracnetics
# !pip install --upgrade pyvis
import fracnetics as fn
import gymnasium as gym
from matplotlib import pyplot as plt
import statistics
from gymnasium.wrappers import RecordVideo
from pyvis.network import Network # for network visualization 
from IPython.display import HTML # for network visualization
# Out:
# Requirement already satisfied: fracnetics in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.7.11)
# Requirement already satisfied: pybind11>=2.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fracnetics) (3.0.0)
#
# [notice] A new release of pip is available: 25.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pyvis in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.3.2)
# Requirement already satisfied: ipython>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyvis) (8.11.0)
# Requirement already satisfied: jinja2>=2.9.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyvis) (3.1.2)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyvis) (3.0.4)
# Requirement already satisfied: networkx>=1.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyvis) (3.4.2)
# Requirement already satisfied: backcall in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: decorator in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (3.0.38)
# Requirement already satisfied: pygments>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (2.14.0)
# Requirement already satisfied: stack-data in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (5.9.0)
# Requirement already satisfied: pexpect>4.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: appnope in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis) (0.1.3)
# Requirement already satisfied: wcwidth in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->pyvis) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2>=2.9.6->pyvis) (2.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.2.1)
# Requirement already satisfied: pure-eval in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
#
# [notice] A new release of pip is available: 25.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Initializing the Population
#
# Here we initialize the population for Fracnetics to solve the cartpole problem.
#
# Key parameters:
# - `seed`: random seed for reproducibility
# - `ni`: number of individuals
# - `jn` / `jnf`: judgment nodes and functions
# - `pn` / `pnf`: perceptron nodes and functions
# - `fractalJudgment`: enables/disables fractal-based judgment (not relevant in this tutorial)

# %%
seed=17
# Initialize the population
pop = fn.Population(
    seed=seed,
    ni=1000,       # number of individuals
    jn=1,         # judgment nodes
    jnf=8,        # judgment node functions
    pn=2,         # perceptron nodes
    pnf=4,        # perceptron node functions
    fractalJudgment=False
)

# %% [markdown]
# Hints:
#
# - We just initialized one jn and two pn because networks can grow and shrink and therefore can add judgment nodes during the evolution. See also our paper: https://link.springer.com/chapter/10.1007/978-3-031-90062-4_18
# - We initialized 4 judgment nodes functions (jnf) because the observation is a ndarray with shape (4,)
# - We initializes 2 processing node functions (2) because the action is a ndarray with shape (1,) which can take values {0, 1}

# %%
# Set input feature boundaries (based on CartPole state space)
minFeatures = [ -2.5, -2.5, -10, -10, -6.2831855, -10, -0, -0 ] 
maxFeatures = [ 2.5, 2.5, 10, 10, 6.2831855, 10, 1, 1 ]
pop.setAllNodeBoundaries(minFeatures, maxFeatures)

# %% [markdown]
# ## Training the Population
#
# The population is trained over 300 generations.
# Each generation involves:
# 1. Fitness evaluation in the Gym environment
# 2. Selection (Tournament Selection)
# 3. Mutation (edges)
# 4. Crossover
# 5. Adding/Deleting nodes
#
# The best fitness score from each generation is stored and plotted.

# %%
# Training environment
env = gym.make("LunarLander-v3")
fitnessProgess = []

nTimes200 = 0
maxFitness = 0
g = 0
while maxFitness < 200 or nTimes200 <= 10:
    pop.gymnasium(
        env,
        dMax=10,
        maxSteps=1000,
        maxConsecutiveP=10,
        worstFitness=0,
        seed=seed+g
    )
    # Selection
    pop.tournamentSelection(
        N=5, # tournament size
        E=1 # number of safed elite
        )
    
    # Add/Delete nodes
    pop.callAddDelNodes(minFeatures, maxFeatures)

    # Mutations
    pop.callEdgeMutation(
        probInnerNodes = 0.05, # probability of changing an edge of jn or pn
        probStartNode = 0.05 # probability of changing an edge of the start node
        )

    pop.callBoundaryMutationEdgeSizeDependingSigma(0.05,1)
    # Crossover (recombination)
    pop.crossover(probability=0.05)

    maxFitness = pop.bestFit
    if maxFitness >= 200:
        nTimes200 += 1
    else:
        nTimes200 = 0

    g += 1
    print(f"Generation: {g} | Maximal Fitness: {maxFitness}")
    fitnessProgess.append([ind.fitness for ind in pop.individuals]) # append fitness of each individual for boxplot chart
# Out:
# Generation: 1 | Maximal Fitness: 20.27112579345703
# Generation: 2 | Maximal Fitness: 0.0
# Generation: 3 | Maximal Fitness: 0.0
# Generation: 4 | Maximal Fitness: 20.94660186767578
# Generation: 5 | Maximal Fitness: 16.802833557128906
# Generation: 6 | Maximal Fitness: 11.565284729003906
# Generation: 7 | Maximal Fitness: 47.186737060546875
# Generation: 8 | Maximal Fitness: 0.0
# Generation: 9 | Maximal Fitness: 26.342010498046875
# Generation: 10 | Maximal Fitness: 0.0
# Generation: 11 | Maximal Fitness: 19.640113830566406
# Generation: 12 | Maximal Fitness: 6.2520294189453125
# Generation: 13 | Maximal Fitness: 32.81517028808594
# Generation: 14 | Maximal Fitness: 0.0
# Generation: 15 | Maximal Fitness: 0.0
# Generation: 16 | Maximal Fitness: 19.77825164794922
# Generation: 17 | Maximal Fitness: 17.20281219482422
# Generation: 18 | Maximal Fitness: 25.340377807617188
# Generation: 19 | Maximal Fitness: 0.0
# Generation: 20 | Maximal Fitness: 0.0
# Generation: 21 | Maximal Fitness: 0.0
# Generation: 22 | Maximal Fitness: 9.835060119628906
# Generation: 23 | Maximal Fitness: 0.0
# Generation: 24 | Maximal Fitness: 39.06610107421875
# Generation: 25 | Maximal Fitness: 49.08447265625
# Generation: 26 | Maximal Fitness: 4.95306396484375
# Generation: 27 | Maximal Fitness: 54.361602783203125
# Generation: 28 | Maximal Fitness: 0.0
# Generation: 29 | Maximal Fitness: 7.226715087890625
# Generation: 30 | Maximal Fitness: 0.0
# Generation: 31 | Maximal Fitness: 28.10888671875
# Generation: 32 | Maximal Fitness: 0.0
# Generation: 33 | Maximal Fitness: 0.0
# Generation: 34 | Maximal Fitness: 0.06195068359375
# Generation: 35 | Maximal Fitness: 6.9704437255859375
# Generation: 36 | Maximal Fitness: 0.0
# Generation: 37 | Maximal Fitness: 4.156211853027344
# Generation: 38 | Maximal Fitness: 0.0
# Generation: 39 | Maximal Fitness: 25.632125854492188
# Generation: 40 | Maximal Fitness: 0.0
# Generation: 41 | Maximal Fitness: 0.0
# Generation: 42 | Maximal Fitness: 0.0
# Generation: 43 | Maximal Fitness: 24.4532470703125
# Generation: 44 | Maximal Fitness: 0.0
# Generation: 45 | Maximal Fitness: 0.0
# Generation: 46 | Maximal Fitness: 0.0
# Generation: 47 | Maximal Fitness: 0.0
# Generation: 48 | Maximal Fitness: 2.8684234619140625
# Generation: 49 | Maximal Fitness: 0.0
# Generation: 50 | Maximal Fitness: 0.0
# Generation: 51 | Maximal Fitness: 0.0
# Generation: 52 | Maximal Fitness: 35.685546875
# Generation: 53 | Maximal Fitness: 0.0
# Generation: 54 | Maximal Fitness: 0.0
# Generation: 55 | Maximal Fitness: 0.0
# Generation: 56 | Maximal Fitness: 0.0
# Generation: 57 | Maximal Fitness: 10.631370544433594
# Generation: 58 | Maximal Fitness: 0.0
# Generation: 59 | Maximal Fitness: 0.0
# Generation: 60 | Maximal Fitness: 0.0
# Generation: 61 | Maximal Fitness: 1.4371490478515625
# Generation: 62 | Maximal Fitness: 9.092399597167969
# Generation: 63 | Maximal Fitness: 22.482810974121094
# Generation: 64 | Maximal Fitness: 0.0
# Generation: 65 | Maximal Fitness: 0.0
# Generation: 66 | Maximal Fitness: 0.0
# Generation: 67 | Maximal Fitness: 0.0
# Generation: 68 | Maximal Fitness: 0.0
# Generation: 69 | Maximal Fitness: 0.0
# Generation: 70 | Maximal Fitness: 0.0
# Generation: 71 | Maximal Fitness: 0.0
# Generation: 72 | Maximal Fitness: 9.870124816894531
# Generation: 73 | Maximal Fitness: 0.0
# Generation: 74 | Maximal Fitness: 20.2545166015625
# Generation: 75 | Maximal Fitness: 19.191909790039062
# Generation: 76 | Maximal Fitness: 21.679168701171875
# Generation: 77 | Maximal Fitness: 30.133377075195312
# Generation: 78 | Maximal Fitness: 26.04217529296875
# Generation: 79 | Maximal Fitness: 21.94322967529297
# Generation: 80 | Maximal Fitness: 20.683197021484375
# Generation: 81 | Maximal Fitness: 46.19966125488281
# Generation: 82 | Maximal Fitness: 34.39619445800781
# Generation: 83 | Maximal Fitness: 12.822128295898438
# Generation: 84 | Maximal Fitness: 16.7857666015625
# Generation: 85 | Maximal Fitness: 35.07325744628906
# Generation: 86 | Maximal Fitness: 0.0
# Generation: 87 | Maximal Fitness: 0.0
# Generation: 88 | Maximal Fitness: 0.0
# Generation: 89 | Maximal Fitness: 13.959815979003906
# Generation: 90 | Maximal Fitness: 0.0
# Generation: 91 | Maximal Fitness: 0.0
# Generation: 92 | Maximal Fitness: 0.0
# Generation: 93 | Maximal Fitness: 0.0
# Generation: 94 | Maximal Fitness: 0.0
# Generation: 95 | Maximal Fitness: 0.0
# Generation: 96 | Maximal Fitness: 3.1222915649414062
# Generation: 97 | Maximal Fitness: 0.0
# Generation: 98 | Maximal Fitness: 0.0
# Generation: 99 | Maximal Fitness: 0.0
# Generation: 100 | Maximal Fitness: 1.505615234375
# Generation: 101 | Maximal Fitness: 47.016448974609375
# Generation: 102 | Maximal Fitness: 0.0
# Generation: 103 | Maximal Fitness: 0.0
# Generation: 104 | Maximal Fitness: 0.0
# Generation: 105 | Maximal Fitness: 0.0
# Generation: 106 | Maximal Fitness: 64.16012573242188
# Generation: 107 | Maximal Fitness: 0.0
# Generation: 108 | Maximal Fitness: 0.0
# Generation: 109 | Maximal Fitness: 0.0
# Generation: 110 | Maximal Fitness: 45.05747985839844
# Generation: 111 | Maximal Fitness: 0.0
# Generation: 112 | Maximal Fitness: 0.0
# Generation: 113 | Maximal Fitness: 0.0
# Generation: 114 | Maximal Fitness: 8.433212280273438
# Generation: 115 | Maximal Fitness: 0.0
# Generation: 116 | Maximal Fitness: 0.0
# Generation: 117 | Maximal Fitness: 0.0
# Generation: 118 | Maximal Fitness: 0.0
# Generation: 119 | Maximal Fitness: 0.0
# Generation: 120 | Maximal Fitness: 0.0
# Generation: 121 | Maximal Fitness: 0.0
# Generation: 122 | Maximal Fitness: 0.0
# Generation: 123 | Maximal Fitness: 0.0
# Generation: 124 | Maximal Fitness: 0.0
# Generation: 125 | Maximal Fitness: 5.1134185791015625
# Generation: 126 | Maximal Fitness: 0.0
# Generation: 127 | Maximal Fitness: 0.0
# Generation: 128 | Maximal Fitness: 0.0
# Generation: 129 | Maximal Fitness: 30.358108520507812
# Generation: 130 | Maximal Fitness: 0.0
# Generation: 131 | Maximal Fitness: 0.0
# Generation: 132 | Maximal Fitness: 26.87737274169922
# Generation: 133 | Maximal Fitness: 31.177871704101562
# Generation: 134 | Maximal Fitness: 0.0
# Generation: 135 | Maximal Fitness: 0.0
# Generation: 136 | Maximal Fitness: 23.33374786376953
# Generation: 137 | Maximal Fitness: 0.0
# Generation: 138 | Maximal Fitness: 3.116363525390625
# Generation: 139 | Maximal Fitness: 0.0
# Generation: 140 | Maximal Fitness: 0.0
# Generation: 141 | Maximal Fitness: 0.0
# Generation: 142 | Maximal Fitness: 0.0
# Generation: 143 | Maximal Fitness: 0.0
# Generation: 144 | Maximal Fitness: 0.0
# Generation: 145 | Maximal Fitness: 16.405136108398438
# Generation: 146 | Maximal Fitness: 0.0
# Generation: 147 | Maximal Fitness: 0.0
# Generation: 148 | Maximal Fitness: 0.0
# Generation: 149 | Maximal Fitness: 0.0
# Generation: 150 | Maximal Fitness: 0.0
# Generation: 151 | Maximal Fitness: 0.0
# Generation: 152 | Maximal Fitness: 66.19406127929688
# Generation: 153 | Maximal Fitness: 0.0
# Generation: 154 | Maximal Fitness: 0.0
# Generation: 155 | Maximal Fitness: 14.9051513671875
# Generation: 156 | Maximal Fitness: 0.0
# Generation: 157 | Maximal Fitness: 0.23236083984375
# Generation: 158 | Maximal Fitness: 0.0
# Generation: 159 | Maximal Fitness: 0.0
# Generation: 160 | Maximal Fitness: 37.239715576171875
# Generation: 161 | Maximal Fitness: 26.942230224609375
# Generation: 162 | Maximal Fitness: 0.0
# Generation: 163 | Maximal Fitness: 0.0
# Generation: 164 | Maximal Fitness: 2.5111083984375
# Generation: 165 | Maximal Fitness: 0.0
# Generation: 166 | Maximal Fitness: 0.0
# Generation: 167 | Maximal Fitness: 0.0
# Generation: 168 | Maximal Fitness: 3.6684722900390625
# Generation: 169 | Maximal Fitness: 37.36161804199219
# Generation: 170 | Maximal Fitness: 0.0
# Generation: 171 | Maximal Fitness: 0.3057403564453125
# Generation: 172 | Maximal Fitness: 0.0
# Generation: 173 | Maximal Fitness: 4.2022857666015625
# Generation: 174 | Maximal Fitness: 39.79493713378906
# Generation: 175 | Maximal Fitness: 26.527816772460938
# Generation: 176 | Maximal Fitness: 0.0
# Generation: 177 | Maximal Fitness: 0.0
# Generation: 178 | Maximal Fitness: 0.0
# Generation: 179 | Maximal Fitness: 12.520149230957031
# Generation: 180 | Maximal Fitness: 0.0
# Generation: 181 | Maximal Fitness: 0.0
# Generation: 182 | Maximal Fitness: 0.0
# Generation: 183 | Maximal Fitness: 42.70063781738281
# Generation: 184 | Maximal Fitness: 0.0
# Generation: 185 | Maximal Fitness: 8.822647094726562
# Generation: 186 | Maximal Fitness: 25.921844482421875
# Generation: 187 | Maximal Fitness: 33.66053771972656
# Generation: 188 | Maximal Fitness: 0.0
# Generation: 189 | Maximal Fitness: 7.8387908935546875
# Generation: 190 | Maximal Fitness: 0.0
# Generation: 191 | Maximal Fitness: 27.62841796875
# Generation: 192 | Maximal Fitness: 0.0
# Generation: 193 | Maximal Fitness: 0.0
# Generation: 194 | Maximal Fitness: 25.870338439941406
# Generation: 195 | Maximal Fitness: 0.0
# Generation: 196 | Maximal Fitness: 0.0
# Generation: 197 | Maximal Fitness: 0.0
# Generation: 198 | Maximal Fitness: 0.0
# Generation: 199 | Maximal Fitness: 0.0
# Generation: 200 | Maximal Fitness: 0.0
# Generation: 201 | Maximal Fitness: 10.621109008789062
# Generation: 202 | Maximal Fitness: 0.0
# Generation: 203 | Maximal Fitness: 0.0
# Generation: 204 | Maximal Fitness: 0.0
# Generation: 205 | Maximal Fitness: 0.0
# Generation: 206 | Maximal Fitness: 0.0
# Generation: 207 | Maximal Fitness: 28.660629272460938
# Generation: 208 | Maximal Fitness: 0.0
# Generation: 209 | Maximal Fitness: 3.2892303466796875
# Generation: 210 | Maximal Fitness: 0.0
# Generation: 211 | Maximal Fitness: 0.0
# Generation: 212 | Maximal Fitness: 0.0
# Generation: 213 | Maximal Fitness: 0.0
# Generation: 214 | Maximal Fitness: 0.0
# Generation: 215 | Maximal Fitness: 0.0
# Generation: 216 | Maximal Fitness: 0.0
# Generation: 217 | Maximal Fitness: 0.0
# Generation: 218 | Maximal Fitness: 0.0
# Generation: 219 | Maximal Fitness: 0.0
# Generation: 220 | Maximal Fitness: 0.0
# Generation: 221 | Maximal Fitness: 0.0
# Generation: 222 | Maximal Fitness: 0.0
# Generation: 223 | Maximal Fitness: 0.0
# Generation: 224 | Maximal Fitness: 0.0
# Generation: 225 | Maximal Fitness: 0.0
# Generation: 226 | Maximal Fitness: 0.0
# Generation: 227 | Maximal Fitness: 0.0
# Generation: 228 | Maximal Fitness: 0.0
# Generation: 229 | Maximal Fitness: 0.0
# Generation: 230 | Maximal Fitness: 0.0
# Generation: 231 | Maximal Fitness: 0.0
# Generation: 232 | Maximal Fitness: 0.0
# Generation: 233 | Maximal Fitness: 0.0
# Generation: 234 | Maximal Fitness: 0.0
# Generation: 235 | Maximal Fitness: 12.827484130859375
# Generation: 236 | Maximal Fitness: 5.332954406738281
# Generation: 237 | Maximal Fitness: 0.0
# Generation: 238 | Maximal Fitness: 0.0
# Generation: 239 | Maximal Fitness: 0.0
# Generation: 240 | Maximal Fitness: 0.0
# Generation: 241 | Maximal Fitness: 0.0
# Generation: 242 | Maximal Fitness: 0.0
# Generation: 243 | Maximal Fitness: 0.0
# Generation: 244 | Maximal Fitness: 33.883697509765625
# Generation: 245 | Maximal Fitness: 0.0
# Generation: 246 | Maximal Fitness: 0.0
# Generation: 247 | Maximal Fitness: 0.0
# Generation: 248 | Maximal Fitness: 0.0
# Generation: 249 | Maximal Fitness: 0.0
# Generation: 250 | Maximal Fitness: 0.0
# Generation: 251 | Maximal Fitness: 0.0
# Generation: 252 | Maximal Fitness: 0.0
# Generation: 253 | Maximal Fitness: 36.01045227050781
# Generation: 254 | Maximal Fitness: 0.0
# Generation: 255 | Maximal Fitness: 0.0
# Generation: 256 | Maximal Fitness: 0.0
# Generation: 257 | Maximal Fitness: 0.0
# Generation: 258 | Maximal Fitness: 7.3440093994140625
# Generation: 259 | Maximal Fitness: 0.0
# Generation: 260 | Maximal Fitness: 0.0
# Generation: 261 | Maximal Fitness: 0.0
# Generation: 262 | Maximal Fitness: 0.0
# Generation: 263 | Maximal Fitness: 23.074752807617188
# Generation: 264 | Maximal Fitness: 27.884971618652344
# Generation: 265 | Maximal Fitness: 13.025382995605469
# Generation: 266 | Maximal Fitness: 0.0
# Generation: 267 | Maximal Fitness: 0.0
# Generation: 268 | Maximal Fitness: 0.0
# Generation: 269 | Maximal Fitness: 0.0
# Generation: 270 | Maximal Fitness: 0.0
# Generation: 271 | Maximal Fitness: 26.259246826171875
# Generation: 272 | Maximal Fitness: 0.0
# Generation: 273 | Maximal Fitness: 0.0
# Generation: 274 | Maximal Fitness: 0.0
# Generation: 275 | Maximal Fitness: 0.0
# Generation: 276 | Maximal Fitness: 0.0
# Generation: 277 | Maximal Fitness: 0.0
# Generation: 278 | Maximal Fitness: 0.0
# Generation: 279 | Maximal Fitness: 0.0
# Generation: 280 | Maximal Fitness: 0.0
# Generation: 281 | Maximal Fitness: 0.0
# Generation: 282 | Maximal Fitness: 0.0
# Generation: 283 | Maximal Fitness: 0.0
# Generation: 284 | Maximal Fitness: 0.0
# Generation: 285 | Maximal Fitness: 0.0
# Generation: 286 | Maximal Fitness: 0.0
# Generation: 287 | Maximal Fitness: 0.0
# Generation: 288 | Maximal Fitness: 0.0
# Generation: 289 | Maximal Fitness: 0.0
# Generation: 290 | Maximal Fitness: 0.0
# Generation: 291 | Maximal Fitness: 0.0
# Generation: 292 | Maximal Fitness: 0.0
# Generation: 293 | Maximal Fitness: 26.814926147460938
# Generation: 294 | Maximal Fitness: 0.0
# Generation: 295 | Maximal Fitness: 0.0
# Generation: 296 | Maximal Fitness: 0.0
# Generation: 297 | Maximal Fitness: 0.0
# Generation: 298 | Maximal Fitness: 0.0
# Generation: 299 | Maximal Fitness: 0.0
# Generation: 300 | Maximal Fitness: 0.0
# Generation: 301 | Maximal Fitness: 0.0
# Generation: 302 | Maximal Fitness: 0.0
# Generation: 303 | Maximal Fitness: 0.0
# Generation: 304 | Maximal Fitness: 26.603347778320312
# Generation: 305 | Maximal Fitness: 0.8194122314453125
# Generation: 306 | Maximal Fitness: 0.0
# Generation: 307 | Maximal Fitness: 26.79559326171875
# Generation: 308 | Maximal Fitness: 0.0
# Generation: 309 | Maximal Fitness: 0.0
# Generation: 310 | Maximal Fitness: 0.0
# Generation: 311 | Maximal Fitness: 32.47190856933594
# Generation: 312 | Maximal Fitness: 0.0
# Generation: 313 | Maximal Fitness: 0.0
# Generation: 314 | Maximal Fitness: 2.508575439453125
# Generation: 315 | Maximal Fitness: 0.0
# Generation: 316 | Maximal Fitness: 0.0
# Generation: 317 | Maximal Fitness: 0.0
# Generation: 318 | Maximal Fitness: 0.0
# Generation: 319 | Maximal Fitness: 0.0
# Generation: 320 | Maximal Fitness: 0.0
# Generation: 321 | Maximal Fitness: 0.0
# Generation: 322 | Maximal Fitness: 20.134597778320312
# Generation: 323 | Maximal Fitness: 7.296302795410156
# Generation: 324 | Maximal Fitness: 18.737533569335938
# Generation: 325 | Maximal Fitness: 0.0
# Generation: 326 | Maximal Fitness: 0.0
# Generation: 327 | Maximal Fitness: 9.489234924316406
# Generation: 328 | Maximal Fitness: 24.50091552734375
# Generation: 329 | Maximal Fitness: 38.90928649902344
# Generation: 330 | Maximal Fitness: 0.0
# Generation: 331 | Maximal Fitness: 0.0
# Generation: 332 | Maximal Fitness: 0.0
# Generation: 333 | Maximal Fitness: 14.875053405761719
# Generation: 334 | Maximal Fitness: 0.0
# Generation: 335 | Maximal Fitness: 0.0
# Generation: 336 | Maximal Fitness: 0.0
# Generation: 337 | Maximal Fitness: 0.0
# Generation: 338 | Maximal Fitness: 6.328765869140625
# Generation: 339 | Maximal Fitness: 0.0
# Generation: 340 | Maximal Fitness: 0.0
# Generation: 341 | Maximal Fitness: 0.0
# Generation: 342 | Maximal Fitness: 0.0
# Generation: 343 | Maximal Fitness: 0.0
# Generation: 344 | Maximal Fitness: 0.0
# Generation: 345 | Maximal Fitness: 19.689170837402344
# Generation: 346 | Maximal Fitness: 27.607704162597656
# Generation: 347 | Maximal Fitness: 0.0
# Generation: 348 | Maximal Fitness: 0.0
# Generation: 349 | Maximal Fitness: 7.911293029785156
# Generation: 350 | Maximal Fitness: 0.0
# Generation: 351 | Maximal Fitness: 0.0
# Generation: 352 | Maximal Fitness: 0.0
# Generation: 353 | Maximal Fitness: 21.370697021484375
# Generation: 354 | Maximal Fitness: 8.237190246582031
# Generation: 355 | Maximal Fitness: 0.0
# Generation: 356 | Maximal Fitness: 0.0
# Generation: 357 | Maximal Fitness: 14.517745971679688
# Generation: 358 | Maximal Fitness: 4.237144470214844
# Generation: 359 | Maximal Fitness: 21.90520477294922
# Generation: 360 | Maximal Fitness: 29.534439086914062
# Generation: 361 | Maximal Fitness: 0.0
# Generation: 362 | Maximal Fitness: 0.0
# Generation: 363 | Maximal Fitness: 0.0
# Generation: 364 | Maximal Fitness: 0.0
# Generation: 365 | Maximal Fitness: 0.0
# Generation: 366 | Maximal Fitness: 0.0
# Generation: 367 | Maximal Fitness: 0.0
# Generation: 368 | Maximal Fitness: 0.0
# Generation: 369 | Maximal Fitness: 0.0
# Generation: 370 | Maximal Fitness: 0.0
# Generation: 371 | Maximal Fitness: 0.0
# Generation: 372 | Maximal Fitness: 0.0
# Generation: 373 | Maximal Fitness: 0.0
# Generation: 374 | Maximal Fitness: 11.381362915039062
# Generation: 375 | Maximal Fitness: 0.0
# Generation: 376 | Maximal Fitness: 23.46014404296875
# Generation: 377 | Maximal Fitness: 0.0
# Generation: 378 | Maximal Fitness: 0.0
# Generation: 379 | Maximal Fitness: 1.9844970703125
# Generation: 380 | Maximal Fitness: 0.0
# Generation: 381 | Maximal Fitness: 0.0
# Generation: 382 | Maximal Fitness: 5.136558532714844
# Generation: 383 | Maximal Fitness: 0.0
# Generation: 384 | Maximal Fitness: 1.5588531494140625
# Generation: 385 | Maximal Fitness: 0.0
# Generation: 386 | Maximal Fitness: 0.7100677490234375
# Generation: 387 | Maximal Fitness: 0.0
# Generation: 388 | Maximal Fitness: 4.997673034667969
# Generation: 389 | Maximal Fitness: 0.0
# Generation: 390 | Maximal Fitness: 0.0
# Generation: 391 | Maximal Fitness: 12.171615600585938
# Generation: 392 | Maximal Fitness: 0.0
# Generation: 393 | Maximal Fitness: 0.0
# Generation: 394 | Maximal Fitness: 0.0
# Generation: 395 | Maximal Fitness: 0.0
# Generation: 396 | Maximal Fitness: 0.0
# Generation: 397 | Maximal Fitness: 0.0
# Generation: 398 | Maximal Fitness: 0.0
# Generation: 399 | Maximal Fitness: 0.0
# Generation: 400 | Maximal Fitness: 0.0
# Generation: 401 | Maximal Fitness: 0.0
# Generation: 402 | Maximal Fitness: 0.0
# Generation: 403 | Maximal Fitness: 0.0
# Generation: 404 | Maximal Fitness: 2.2919158935546875
# Generation: 405 | Maximal Fitness: 0.0
# Generation: 406 | Maximal Fitness: 0.0
# Generation: 407 | Maximal Fitness: 49.490234375
# Generation: 408 | Maximal Fitness: 12.441070556640625
# Generation: 409 | Maximal Fitness: 31.503219604492188
# Generation: 410 | Maximal Fitness: 0.0
# Generation: 411 | Maximal Fitness: 0.0
# Generation: 412 | Maximal Fitness: 0.0
# Generation: 413 | Maximal Fitness: 0.0
# Generation: 414 | Maximal Fitness: 0.0
# Generation: 415 | Maximal Fitness: 1.6835174560546875
# Generation: 416 | Maximal Fitness: 0.0
# Generation: 417 | Maximal Fitness: 0.0
# Generation: 418 | Maximal Fitness: 0.0
# Generation: 419 | Maximal Fitness: 0.0
# Generation: 420 | Maximal Fitness: 0.0
# Generation: 421 | Maximal Fitness: 0.0
# Generation: 422 | Maximal Fitness: 0.0
# Generation: 423 | Maximal Fitness: 0.0
# Generation: 424 | Maximal Fitness: 0.0
# Generation: 425 | Maximal Fitness: 0.0
# Generation: 426 | Maximal Fitness: 25.55377197265625
# Generation: 427 | Maximal Fitness: 0.0
# Generation: 428 | Maximal Fitness: 0.0
# Generation: 429 | Maximal Fitness: 0.0
# Generation: 430 | Maximal Fitness: 11.265495300292969
# Generation: 431 | Maximal Fitness: 0.0
# Generation: 432 | Maximal Fitness: 8.510154724121094
# Generation: 433 | Maximal Fitness: 34.85566711425781
# Generation: 434 | Maximal Fitness: 0.0
# Generation: 435 | Maximal Fitness: 0.0
# Generation: 436 | Maximal Fitness: 0.0
# Generation: 437 | Maximal Fitness: 0.0
# Generation: 438 | Maximal Fitness: 0.0
# Generation: 439 | Maximal Fitness: 15.557533264160156
# Generation: 440 | Maximal Fitness: 0.0
# Generation: 441 | Maximal Fitness: 0.0
# Generation: 442 | Maximal Fitness: 0.0
# Generation: 443 | Maximal Fitness: 0.0
# Generation: 444 | Maximal Fitness: 0.0
# Generation: 445 | Maximal Fitness: 0.0
# Generation: 446 | Maximal Fitness: 0.0
# Generation: 447 | Maximal Fitness: 0.0
# Generation: 448 | Maximal Fitness: 0.0
# Generation: 449 | Maximal Fitness: 0.0
# Generation: 450 | Maximal Fitness: 0.0
# Generation: 451 | Maximal Fitness: 0.0
# Generation: 452 | Maximal Fitness: 0.60833740234375
# Generation: 453 | Maximal Fitness: 0.0
# Generation: 454 | Maximal Fitness: 0.0
# Generation: 455 | Maximal Fitness: 15.784881591796875
# Generation: 456 | Maximal Fitness: 17.000091552734375
# Generation: 457 | Maximal Fitness: 0.0
# Generation: 458 | Maximal Fitness: 0.0
# Generation: 459 | Maximal Fitness: 0.0
# Generation: 460 | Maximal Fitness: 0.0
# Generation: 461 | Maximal Fitness: 0.0
# Generation: 462 | Maximal Fitness: 0.0
# Generation: 463 | Maximal Fitness: 0.0
# Generation: 464 | Maximal Fitness: 48.34501647949219
# Generation: 465 | Maximal Fitness: 24.543724060058594
# Generation: 466 | Maximal Fitness: 0.0
# Generation: 467 | Maximal Fitness: 0.0
# Generation: 468 | Maximal Fitness: 0.0
# Generation: 469 | Maximal Fitness: 0.0
# Generation: 470 | Maximal Fitness: 15.293052673339844
# Generation: 471 | Maximal Fitness: 0.0
# Generation: 472 | Maximal Fitness: 0.0
# Generation: 473 | Maximal Fitness: 0.0
# Generation: 474 | Maximal Fitness: 14.867835998535156
# Generation: 475 | Maximal Fitness: 0.0
# Generation: 476 | Maximal Fitness: 50.42137145996094
# Generation: 477 | Maximal Fitness: 0.0
# Generation: 478 | Maximal Fitness: 16.218477249145508
# Generation: 479 | Maximal Fitness: 53.302734375
# Generation: 480 | Maximal Fitness: 0.0
# Generation: 481 | Maximal Fitness: 0.0
# Generation: 482 | Maximal Fitness: 0.0
# Generation: 483 | Maximal Fitness: 0.0
# Generation: 484 | Maximal Fitness: 0.0
# Generation: 485 | Maximal Fitness: 0.0
# Generation: 486 | Maximal Fitness: 0.0
# Generation: 487 | Maximal Fitness: 0.0
# Generation: 488 | Maximal Fitness: 0.0
# Generation: 489 | Maximal Fitness: 0.0
# Generation: 490 | Maximal Fitness: 0.0
# Generation: 491 | Maximal Fitness: 0.0
# Generation: 492 | Maximal Fitness: 0.33290863037109375
# Generation: 493 | Maximal Fitness: 20.45439910888672
# Generation: 494 | Maximal Fitness: 0.0
# Generation: 495 | Maximal Fitness: 0.0
# Generation: 496 | Maximal Fitness: 0.0
# Generation: 497 | Maximal Fitness: 0.0
# Generation: 498 | Maximal Fitness: 45.12593078613281
# Generation: 499 | Maximal Fitness: 0.0
# Generation: 500 | Maximal Fitness: 1.2056485414505005
# Generation: 501 | Maximal Fitness: 0.0
# Generation: 502 | Maximal Fitness: 0.0
# Generation: 503 | Maximal Fitness: 0.0
# Generation: 504 | Maximal Fitness: 0.0
# Generation: 505 | Maximal Fitness: 0.0
# Generation: 506 | Maximal Fitness: 0.0
# Generation: 507 | Maximal Fitness: 0.0
# Generation: 508 | Maximal Fitness: 14.354171752929688
# Generation: 509 | Maximal Fitness: 0.0
# Generation: 510 | Maximal Fitness: 0.0
# Generation: 511 | Maximal Fitness: 0.0
# Generation: 512 | Maximal Fitness: 0.0
# Generation: 513 | Maximal Fitness: 0.0
# Generation: 514 | Maximal Fitness: 0.0
# Generation: 515 | Maximal Fitness: 0.0
# Generation: 516 | Maximal Fitness: 187.7474365234375
# Generation: 517 | Maximal Fitness: 0.0
# Generation: 518 | Maximal Fitness: 0.0
# Generation: 519 | Maximal Fitness: 0.0
# Generation: 520 | Maximal Fitness: 22.309829711914062
# Generation: 521 | Maximal Fitness: 0.0
# Generation: 522 | Maximal Fitness: 0.0
# Generation: 523 | Maximal Fitness: 0.0
# Generation: 524 | Maximal Fitness: 0.0
# Generation: 525 | Maximal Fitness: 0.0
# Generation: 526 | Maximal Fitness: 0.0
# Generation: 527 | Maximal Fitness: 0.0
# Generation: 528 | Maximal Fitness: 0.0
# Generation: 529 | Maximal Fitness: 2.125396728515625
# Generation: 530 | Maximal Fitness: 0.0
# Generation: 531 | Maximal Fitness: 0.0
# Generation: 532 | Maximal Fitness: 0.0
# Generation: 533 | Maximal Fitness: 0.0
# Generation: 534 | Maximal Fitness: 0.0
# Generation: 535 | Maximal Fitness: 0.0
# Generation: 536 | Maximal Fitness: 9.404548645019531
# Generation: 537 | Maximal Fitness: 0.0
# Generation: 538 | Maximal Fitness: 0.0
# Generation: 539 | Maximal Fitness: 43.12158203125
# Generation: 540 | Maximal Fitness: 21.84748077392578
# Generation: 541 | Maximal Fitness: 8.838653564453125
# Generation: 542 | Maximal Fitness: 0.0
# Generation: 543 | Maximal Fitness: 0.0
# Generation: 544 | Maximal Fitness: 4.3995819091796875
# Generation: 545 | Maximal Fitness: 0.0
# Generation: 546 | Maximal Fitness: 10.902488708496094
# Generation: 547 | Maximal Fitness: 5.867179870605469
# Generation: 548 | Maximal Fitness: 1.9664459228515625
# Generation: 549 | Maximal Fitness: 0.0
# Generation: 550 | Maximal Fitness: 0.0
# Generation: 551 | Maximal Fitness: 22.920455932617188
# Generation: 552 | Maximal Fitness: 0.0
# Generation: 553 | Maximal Fitness: 0.0
# Generation: 554 | Maximal Fitness: 0.0
# Generation: 555 | Maximal Fitness: 0.0
# Generation: 556 | Maximal Fitness: 0.0
# Generation: 557 | Maximal Fitness: 11.274856567382812
# Generation: 558 | Maximal Fitness: 0.0
# Generation: 559 | Maximal Fitness: 0.0
# Generation: 560 | Maximal Fitness: 39.0489501953125
# Generation: 561 | Maximal Fitness: 0.0
# Generation: 562 | Maximal Fitness: 0.0
# Generation: 563 | Maximal Fitness: 24.764923095703125
# Generation: 564 | Maximal Fitness: 0.0
# Generation: 565 | Maximal Fitness: 0.0
# Generation: 566 | Maximal Fitness: 0.0
# Generation: 567 | Maximal Fitness: 0.0
# Generation: 568 | Maximal Fitness: 0.0
# Generation: 569 | Maximal Fitness: 0.0
# Generation: 570 | Maximal Fitness: 0.0
# Generation: 571 | Maximal Fitness: 22.159751892089844
# Generation: 572 | Maximal Fitness: 0.0
# Generation: 573 | Maximal Fitness: 12.17242431640625
# Generation: 574 | Maximal Fitness: 0.0
# Generation: 575 | Maximal Fitness: 0.0
# Generation: 576 | Maximal Fitness: 9.840995788574219
# Generation: 577 | Maximal Fitness: 0.0
# Generation: 578 | Maximal Fitness: 0.0
# Generation: 579 | Maximal Fitness: 0.0
# Generation: 580 | Maximal Fitness: 0.0
# Generation: 581 | Maximal Fitness: 0.0
# Generation: 582 | Maximal Fitness: 0.0
# Generation: 583 | Maximal Fitness: 0.0
# Generation: 584 | Maximal Fitness: 0.0
# Generation: 585 | Maximal Fitness: 0.0
# Generation: 586 | Maximal Fitness: 0.0
# Generation: 587 | Maximal Fitness: 0.0
# Generation: 588 | Maximal Fitness: 0.0
# Generation: 589 | Maximal Fitness: 0.0
# Generation: 590 | Maximal Fitness: 8.062820434570312
# Generation: 591 | Maximal Fitness: 0.0
# Generation: 592 | Maximal Fitness: 0.0
# Generation: 593 | Maximal Fitness: 0.0
# Generation: 594 | Maximal Fitness: 0.0
# Generation: 595 | Maximal Fitness: 0.0
# Generation: 596 | Maximal Fitness: 14.078323364257812
# Generation: 597 | Maximal Fitness: 7.963035583496094
# Generation: 598 | Maximal Fitness: 0.0
# Generation: 599 | Maximal Fitness: 0.0
# Generation: 600 | Maximal Fitness: 0.0
# Generation: 601 | Maximal Fitness: 0.0
# Generation: 602 | Maximal Fitness: 0.0
# Generation: 603 | Maximal Fitness: 0.0
# Generation: 604 | Maximal Fitness: 0.0
# Generation: 605 | Maximal Fitness: 30.621047973632812
# Generation: 606 | Maximal Fitness: 2.6800003051757812
# Generation: 607 | Maximal Fitness: 0.0
# Generation: 608 | Maximal Fitness: 0.0
# Generation: 609 | Maximal Fitness: 0.0
# Generation: 610 | Maximal Fitness: 0.0
# Generation: 611 | Maximal Fitness: 0.0
# Generation: 612 | Maximal Fitness: 0.0
# Generation: 613 | Maximal Fitness: 0.0
# Generation: 614 | Maximal Fitness: 0.0
# Generation: 615 | Maximal Fitness: 0.0
# Generation: 616 | Maximal Fitness: 0.0
# Generation: 617 | Maximal Fitness: 0.0
# Generation: 618 | Maximal Fitness: 0.0
# Generation: 619 | Maximal Fitness: 0.0
# Generation: 620 | Maximal Fitness: 4.56805419921875
# Generation: 621 | Maximal Fitness: 0.0
# Generation: 622 | Maximal Fitness: 11.271156311035156
# Generation: 623 | Maximal Fitness: 11.656280517578125
# Generation: 624 | Maximal Fitness: 0.0
# Generation: 625 | Maximal Fitness: 0.0
# Generation: 626 | Maximal Fitness: 0.0
# Generation: 627 | Maximal Fitness: 0.0
# Generation: 628 | Maximal Fitness: 0.0
# Generation: 629 | Maximal Fitness: 0.0
# Generation: 630 | Maximal Fitness: 0.0
# Generation: 631 | Maximal Fitness: 0.0
# Generation: 632 | Maximal Fitness: 0.0
# Generation: 633 | Maximal Fitness: 0.0
# Generation: 634 | Maximal Fitness: 0.0
# Generation: 635 | Maximal Fitness: 0.0
# Generation: 636 | Maximal Fitness: 0.0
# Generation: 637 | Maximal Fitness: 0.0
# Generation: 638 | Maximal Fitness: 41.37541198730469
# Generation: 639 | Maximal Fitness: 0.0
# Generation: 640 | Maximal Fitness: 0.0
# Generation: 641 | Maximal Fitness: 4.934295654296875
# Generation: 642 | Maximal Fitness: 0.0
# Generation: 643 | Maximal Fitness: 22.932586669921875
# Generation: 644 | Maximal Fitness: 0.0
# Generation: 645 | Maximal Fitness: 33.44244384765625
# Generation: 646 | Maximal Fitness: 0.0
# Generation: 647 | Maximal Fitness: 8.188407897949219
# Generation: 648 | Maximal Fitness: 0.0
# Generation: 649 | Maximal Fitness: 0.0
# Generation: 650 | Maximal Fitness: 0.0
# Generation: 651 | Maximal Fitness: 0.0
# Generation: 652 | Maximal Fitness: 21.733551025390625
# Generation: 653 | Maximal Fitness: 0.0
# Generation: 654 | Maximal Fitness: 0.0
# Generation: 655 | Maximal Fitness: 1.67303466796875
# Generation: 656 | Maximal Fitness: 24.321250915527344
# Generation: 657 | Maximal Fitness: 19.614540100097656
# Generation: 658 | Maximal Fitness: 0.0
# Generation: 659 | Maximal Fitness: 6.1326751708984375
# Generation: 660 | Maximal Fitness: 0.0
# Generation: 661 | Maximal Fitness: 0.0
# Generation: 662 | Maximal Fitness: 27.575401306152344
# Generation: 663 | Maximal Fitness: 0.0
# Generation: 664 | Maximal Fitness: 15.500022888183594
# Generation: 665 | Maximal Fitness: 0.0
# Generation: 666 | Maximal Fitness: 0.0
# Generation: 667 | Maximal Fitness: 0.0
# Generation: 668 | Maximal Fitness: 0.0
# Generation: 669 | Maximal Fitness: 0.0
# Generation: 670 | Maximal Fitness: 0.0
# Generation: 671 | Maximal Fitness: 0.0
# Generation: 672 | Maximal Fitness: 0.0
# Generation: 673 | Maximal Fitness: 0.0
# Generation: 674 | Maximal Fitness: 21.541053771972656
# Generation: 675 | Maximal Fitness: 0.0
# Generation: 676 | Maximal Fitness: 0.0
# Generation: 677 | Maximal Fitness: 18.870140075683594
# Generation: 678 | Maximal Fitness: 16.11096954345703
# Generation: 679 | Maximal Fitness: 6.891441345214844
# Generation: 680 | Maximal Fitness: 20.423828125
# Generation: 681 | Maximal Fitness: 0.0
# Generation: 682 | Maximal Fitness: 0.0
# Generation: 683 | Maximal Fitness: 0.0
# Generation: 684 | Maximal Fitness: 12.317276000976562
# Generation: 685 | Maximal Fitness: 38.946990966796875
# Generation: 686 | Maximal Fitness: 0.0
# Generation: 687 | Maximal Fitness: 0.0
# Generation: 688 | Maximal Fitness: 0.0
# Generation: 689 | Maximal Fitness: 0.0
# Generation: 690 | Maximal Fitness: 0.0
# Generation: 691 | Maximal Fitness: 10.62933349609375
# Generation: 692 | Maximal Fitness: 0.0
# Generation: 693 | Maximal Fitness: 0.0
# Generation: 694 | Maximal Fitness: 0.0
# Generation: 695 | Maximal Fitness: 41.14410400390625
# Generation: 696 | Maximal Fitness: 2.6881561279296875
# Generation: 697 | Maximal Fitness: 0.0
# Generation: 698 | Maximal Fitness: 0.0
# Generation: 699 | Maximal Fitness: 6.4167327880859375
# Generation: 700 | Maximal Fitness: 12.418998718261719
# Generation: 701 | Maximal Fitness: 45.788909912109375
# Generation: 702 | Maximal Fitness: 0.0
# Generation: 703 | Maximal Fitness: 25.462486267089844
# Generation: 704 | Maximal Fitness: 0.0
# Generation: 705 | Maximal Fitness: 0.0
# Generation: 706 | Maximal Fitness: 0.0
# Generation: 707 | Maximal Fitness: 0.0
# Generation: 708 | Maximal Fitness: 0.0
# Generation: 709 | Maximal Fitness: 0.0
# Generation: 710 | Maximal Fitness: 4.79638671875
# Generation: 711 | Maximal Fitness: 13.465736389160156
# Generation: 712 | Maximal Fitness: 0.0
# Generation: 713 | Maximal Fitness: 0.0
# Generation: 714 | Maximal Fitness: 0.0
# Generation: 715 | Maximal Fitness: 6.1946258544921875
# Generation: 716 | Maximal Fitness: 0.0
# Generation: 717 | Maximal Fitness: 7.771385192871094
# Generation: 718 | Maximal Fitness: 0.0
# Generation: 719 | Maximal Fitness: 22.167940139770508

# %%
# Plot fitness progression
plt.figure(figsize=(15, 6))
plt.boxplot(fitnessProgess, whis=2, sym=".")
plt.title("Fitness Progress")
plt.xlabel("Generation")
plt.ylabel("Fitness")
ticks = range(0,len(fitnessProgess), 10)
plt.xticks(ticks,labels = ticks)
plt.show()

# %%
ticks = range(1, 100 + 1, 5)
labels = [f"Label {i}" for i in ticks]
print(labels)

# %% [markdown]
# ## Inspecting the Best Individual
#
# Now we inspect the best individual:
# - Start node and its edges
# - Inner node types, functions, edges, and boundaries
#
# Because the Genetic Network Programming is **not** a Blackbox-Model

# %%
pop.individuals[-1].fitness
print(f"Start Node: {pop.individuals[-1].startNode.edges}")
for node in pop.individuals[-1].innerNodes:
  print(f"Type: {node.type} | Function: {node.f} Edges: {node.edges} | Boundaries: {node.boundaries}")

# %% [markdown]
# We can also visualize the network in a plot, for example using the pyvis package.
#
# Colors:
#
# - Start node =
# - Processing nodes =
# - Judgment nodes =
#
# Tip: You can view the boundaries of an edge by hovering over it with your mouse.

# %%
net = Network(notebook=True, directed=True, cdn_resources="in_line")
net.force_atlas_2based()
individual = pop.individuals[-1]
processingFunctionNames = ["do nothing", "fire left orientation engine", "fire main engine", "fire right orientation engine"]
judgmentFunctionNames = ["x", "y", "linear velocities x", "linear velocities y", "angle", "angular velocity", "left contact", "right contact"]

# adding start node
net.add_node(-1, label=individual.startNode.type, color = "#635b3e")

# adding inner nodes
for node in individual.innerNodes:
    # set color
    if node.type == "J":
        color = "#3e6341"
        net.add_node(node.id, label=f"F: {judgmentFunctionNames[node.f]}", color=color)
    elif node.type == "P":
        color = "#372f61"
        net.add_node(node.id, label=f"F: {processingFunctionNames[node.f]}", color=color)
    else:
        color = None
        
for node in individual.innerNodes:
    for idx, edge in enumerate(node.edges):
        if node.type == "J":
            edgeLabel = f"{node.boundaries[idx]} bis {node.boundaries[idx+1]}"
            net.add_edge(node.id, edge, title = edgeLabel,
                    font={'size': 14, 'color': '#3e6341', 'align': 'horizontal'})
        else:
            net.add_edge(node.id, edge,
                    font={'size': 14, 'color': '#372f61', 'align': 'horizontal'})
        
# adding start node edge 
net.add_edge(-1, individual.startNode.edges[0])
net.save_graph("cartpole_solution.html")
HTML(filename="cartpole_solution.html")

# %% [markdown]
# ## Validation of the Best Individual
#
# The best individual is validated in a fresh environment.
# We compute the average fitness across multiple runs.

# %%
env = gym.make("CartPole-v1")
validationResults = []
for v in range(10):
    pop.gymnasium(
          env,
          dMax=10,
          maxSteps=500,
          maxConsecutiveP=10,
          worstFitness=0,
          seed=seed+v)
    validationResults.append(pop.bestFit)
print(f"Average Fitnes of Validations: {statistics.mean(validationResults)}")

# %% [markdown]
# ## Rendering and Recording the Best Run
#
# Finally, we run the environment in `rgb_array` mode and use `RecordVideo`
# to save a video of the best individual playing CartPole. You can find the video in the nodebook folder "videos".

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
env = RecordVideo(env, video_folder="videos", name_prefix="cartpole")

# Keep only the best individual
pop.individuals = [pop.individuals[-1]]

# Record a run
pop.gymnasium(
    env,
    dMax=10,
    maxSteps=500,
    maxConsecutiveP=5,
    worstFitness=0,
    seed=seed
)
env.close()
