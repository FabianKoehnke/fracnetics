# %% [markdown]
# # Lunar Lander Notebook
# This notebook demonstrates GNP landing a spacecraft.

# %% [markdown]
# # Small Tutorial Using Fracnetics
#
# ## Summary 🔭
#
# This notebook demonstrates how to use the **Fracnetics** library to solve the CartPole environment problem from Gymnasium (fork from OpenAI Gym).
#
# Fractnetics is a Python library for **Genetic Network Programming (GNP)** enhanced with fractal geometry, which means it a subfield of Evolutionary Algorithms.
#
# ## Lunar Lander
#
# The Lunar Lander problem is a classic reinforcement learning task where an agent must safely land a spacecraft on a designated landing pad. The lander can control its main and side thrusters to adjust its position and velocity. The goal is to land softly and upright, while avoiding crashes or going out of bounds. Rewards are given for touching down gently and penalties for collisions, fuel use, or leaving the landing area. This problem tests an agent’s ability to balance precision control with strategic planning under continuous dynamics.
#
# ![Beschreibung](https://gymnasium.farama.org/_images/lunar_lander.gif)
#
# ## Evolutionary Aglortihms 🧬
#
# Evolutionary Algorithms are a family of optimization techniques inspired by the process of natural evolution. They work by maintaining a **population** of candidate solutions, which evolve over time through operations such as **selection, mutation, and crossover**. The idea is to iteratively improve solutions by mimicking survival of the fittest, where better solutions are more likely to be chosen and combined to form new ones. EAs are especially useful for solving complex, nonlinear, and high-dimensional problems where traditional optimization methods may fail.
#
# ## Genetic Network Programming 🦾
#
# Genetic Network Programming is a branch of evolutionary computation that represents solutions as **networks** of nodes rather than as linear strings (like in Genetic Algorithms). Each node corresponds to a function, decision, or action, and the network’s structure allows for recurrent flows of control. This enables GNP to model adaptive, flexible, and memory-dependent behaviors. It has been applied successfully in areas such as robotics, decision-making systems, and dynamic optimization tasks.
#
# ## Next 🔥
# In this tutorial we will initialize a population, train it, validate it, and finally record a run.
#
# Checkout Fracnetics and Gymnasium here:
#
# - Fracnetics: https://github.com/FabianKoehnke/fracnetics
# - Gymnasium: https://gymnasium.farama.org/

# %% [markdown]
# ## Install and Load Packages

# %%
# !pip install --upgrade fracnetics
# !pip install --upgrade pyvis
import fracnetics as fn
import gymnasium as gym
from matplotlib import pyplot as plt
import statistics
from gymnasium.wrappers import RecordVideo
from pyvis.network import Network # for network visualization 
from IPython.display import HTML # for network visualization
from IPython.display import clear_output
from matplotlib.animation import FuncAnimation
import copy
import math
import time 
import numpy as np
from IPython.display import IFrame

# %% [markdown]
# ## Initializing the Population
#
# Here we initialize the population for Fracnetics to solve the cartpole problem.
#
# Key parameters:
# - `seed`: random seed for reproducibility
# - `ni`: number of individuals
# - `jn` / `jnf`: judgment nodes and functions
# - `pn` / `pnf`: perceptron nodes and functions
# - `fractalJudgment`: enables/disables fractal-based judgment (not relevant in this tutorial)

# %%
seed=5
# Initialize the population
pop = fn.Population(
    seed=seed,
    ni=50,       # number of individuals
    jn=1,         # judgment nodes
    jnf=8,        # judgment node functions
    pn=2,         # processing nodes
    pnf=4,        # processing node functions
    fractalJudgment=False,
    nFeatureValues=[0,0,0,0,0,0,2,2]
)

# %% [markdown]
# Hints:
#
# - We just initialized one jn and two pn because networks can grow and shrink and therefore can add judgment nodes during the evolution. See also our paper: https://link.springer.com/chapter/10.1007/978-3-031-90062-4_18
# - We initialized 4 judgment nodes functions (jnf) because the observation is a ndarray with shape (4,)
# - We initializes 2 processing node functions (2) because the action is a ndarray with shape (1,) which can take values {0, 1}

# %%
# Set input feature boundaries (based on CartPole state space)
minFeatures = [-2.5, -2.5, -10, -10, -6.2831855, -10, 0, 0]
maxFeatures = [2.5, 2.5, 10, 10, 6.2831855, 10, 1, 1]
pop.setAllNodeBoundaries(minFeatures, maxFeatures)

# %% [markdown]
# ## Helperfunctions

# %%
def renderVideos(N, pop, generation = None):

    popRender = fn.Population(
    seed=seed,
    ni=1,       # number of individuals
    jn=1,         # judgment nodes
    jnf=8,        # judgment node functions
    pn=2,         # processing nodes
    pnf=4,        # processing node functions
    fractalJudgment=False,
    nFeatureValues=[0,0,0,0,0,0,2,2]
    )
    
    popRender.individuals = copy.deepcopy([pop.individuals[pop.indicesElite[0]]])
 
    for i in range(N):
        env = gym.make("LunarLander-v3", render_mode="rgb_array", gravity=-10.0)
        env = RecordVideo(env, video_folder="videos", name_prefix=f"lunarlander_generation{g}_seed{i}")
        
        # Keep only the best individual
        popRender = copy.deepcopy(pop)
        popRender.individuals = [popRender.individuals[popRender.indicesElite[0]]]
        
        # Record a run
        popRender.gymnasium(
            env,
            dMax=10_000,
            maxSteps=1500,
            maxConsecutiveP=1_000_000,
            worstFitness=worstFitness,
            seed=i
        )
        env.close()
        print(f"Fitness: {popRender.individuals[-1].fitness}")

# %%
def plotNetwork(individual, filename, justUsedNodes = False, justUsedEdges = False):
    
    net = Network(notebook=True, directed=True, cdn_resources="in_line")
    net.force_atlas_2based()
    processingFunctionNames = ["do nothing", "fire left orientation engine", "fire main engine", "fire right orientation engine"]
    judgmentFunctionNames = ["x", "y", "linear velocities x", "linear velocities y", "angle", "angular velocity", "left contact", "right contact"]
    
    # adding start node
    net.add_node(-1, label=individual.startNode.type, color = "#635b3e")
    
    # adding inner nodes
    for node in individual.innerNodes:
        if justUsedNodes == True and node.used == False:
            continue
        # set color
        if node.type == "J":
            if node.used == True:
                color = "#3e6341"
            else:
                color = "#e0ebe1"
            net.add_node(node.id, label=f"ID: {node.id} F: {judgmentFunctionNames[node.f]} TC: {node.traverseCounter}", color=color)
        elif node.type == "P":
            if node.used == True:
                color = "#372f61"
            else:
                color = "#e0ddee"
            net.add_node(node.id, label=f"ID: {node.id} F: {processingFunctionNames[node.f]} TC: {node.traverseCounter}", color=color)
        else:
            color = None

    # adding edges
    for node in individual.innerNodes:
        if justUsedNodes == True and node.used == False:
            continue
            
        for idx, edge in enumerate(node.edges):
            if justUsedEdges == True and individual.innerNodes[edge].used == False:
                continue
                
            if node.type == "J":
                edgeLabel = f"{node.boundaries[idx]} bis {node.boundaries[idx+1]}"
                net.add_edge(node.id, edge, title = edgeLabel,
                        font={'size': 14, 'color': '#3e6341', 'align': 'horizontal'})
            else:
                net.add_edge(node.id, edge,
                        font={'size': 14, 'color': '#372f61', 'align': 'horizontal'})
            
    # adding start node edge 
    net.add_edge(-1, individual.startNode.edges[0])
    net.save_graph(filename)
    return IFrame(src=filename, width="100%", height="500px")
    #return display(HTML(filename=filename))

# %%
def checkNetworkIDs(pop):
    for ind in pop.individuals:
        for idx, node in enumerate(ind.innerNodes):
            if idx != node.id:
                print("WRONG ID in NODE")

# %% [markdown]
# ## Training the Population
#
# The population is trained over 300 generations.
# Each generation involves:
# 1. Fitness evaluation in the Gym environment
# 2. Selection (Tournament Selection)
# 3. Mutation (edges)
# 4. Crossover
# 5. Adding/Deleting nodes
#
# The best fitness score from each generation is stored and plotted.

# %% [markdown]
# ## Parameter

# %%
import gc
import random
random.seed(42)

batches = 1
maxSeeds = 5
ema = 5
poolSize = 5
pool = [random.randint(1, 10_000) for _ in range(poolSize)]
fitnessProgess = []
maxFitness = 0
g = 0
nSameFitness = 0
nBatches = 0
start = time.perf_counter()
seeds = [random.randint(1, 10_000) for _ in range(maxSeeds)]
ancor = copy.deepcopy(seeds)
worstFitness = -1000

# %% [markdown]
# ## Simulation

# %%
# Training environment
env = gym.make("LunarLander-v3", continuous=False, gravity=-10.0,
               enable_wind=False, wind_power=0, turbulence_power=0)

#for ind in pop.individuals:
#    ind.fitnessValues = [[None for _ in range(seeds)] for _ in range(ema)]
    #for _ in range(ema):
    #    ind.fitnessValues.append(worstFitness)

fitnessProgess = []
for g in range(2000):

    # 1. Multi-Seed Evaluation (C++ Geschwindigkeit!)
    pop.gymnasiumMultiSeed(env, dMax=50, maxSteps=1000, maxConsecutiveP=10,
                           worstFitness=-500, seeds=seeds)

    # 2. Pareto Objectives berechnen
    #pop.calculateParetoObjectives(landingThreshold=100)

    # 3. Pareto Tournament Selection
    #pop.paretoTournamentSelection(N=2, E_reward=2, E_landing=2)
    pop.tournamentSelection(N=2, E=2)
    
    #maxFitness = statistics.mean(pop.individuals[pop.indicesElite[0]].fitnessValues)
    if g > 0:
        fitnessBefore = maxFitness
    else:
        fitnessBefore = 0
        
    maxFitness = pop.individuals[pop.indicesElite[0]].fitness
    fitnessProgess.append(maxFitness)
    # Add/Delete nodes
    pop.callAddDelNodes(minFeatures, maxFeatures, 0.5, True)

    # Crossover (recombination)
    pop.crossover(
        probability = 0.2, 
        type = "randomWidth",
        traversalNeighbor = True,
        lowerBoundTraversalCounter = 0.99,
        upperBoundTraversalCounter = 1.01
    ) 
        
    pop.callEdgeMutation(
        probInnerNodes = 0.1, # probability of changing an edge of jn or pn
        probStartNode = 0.1,  # probability of changing an edge of the start node
        justUsedNodes = True,
        k = 3
        )

    #pop.callBoundaryMutationFractal(0.02, minFeatures, maxFeatures) # NOTE: overwrites boundaries
    pop.callBoundaryMutationNormal(
        probability = 0.04,
        sigma = 0.05,
        justUsedNodes = True
        )
    pop.callBoundaryMutationUniform(
        probability = 0.04,
        justUsedNodes = True
        )
    
    # Plot fitness progression
    
    plt.figure(figsize=(15, 6))
    #for genIdx, genFit in enumerate(fitnessProgess):
        #plt.scatter([genIdx] * len(genFit), [fit for fit in genFit], color='black', alpha=0.1)
    plt.scatter([i for i in range(len(fitnessProgess))], fitnessProgess, color='black')
        #if genIdx >= 1:
        #    plt.scatter([genIdx] * len(pop.individuals[pop.indicesElite[0]].fitnessValues), genFit[-1], color='black')
    #plt.boxplot(fitnessProgess, whis=2, sym=".")

    plt.title(f"Fitness Progress (Generations: {g+1}) | Batches: {nBatches+1} | Best Fitness: {round(maxFitness,2)} | NN: {len(pop.individuals[pop.indicesElite[0]].innerNodes)} | Time.:{round(time.perf_counter()-start,2)} | Seeds: {len(seeds)}")
    plt.xlabel("Generation")
    plt.ylabel("Fitness")
    ticks = range(0,len(fitnessProgess), math.ceil(len(fitnessProgess)/10))
    plt.xticks(ticks,labels = ticks)
    clear_output(wait=True) 
    plt.show()

    best = pop.individuals[pop.indicesElite[0]]
    print("Per-seed rewards:", best.fitnessValues)
    print("Min:", min(best.fitnessValues))
    print("Max:", max(best.fitnessValues))
    landings = sum(1 for r in best.lastStepRewards if r >= 100)
    landing_rate = landings / len(best.lastStepRewards)
    print(f"Landing rate: {landing_rate:.0%}")
    gc.collect()
    plt.close('all')

    #if fitnessProgess[-1] > 200 and landing_rate > 0.85:
    #if g % 500 == 0:
        #start = seeds[-1] + 1
        #seeds.extend(range(start, start + 3))

    if fitnessBefore == maxFitness:
        counterSameFitness += 1
    else:
        counterSameFitness = 0
        
    #if sum(1 for v in best.fitnessValues if v > 150) / len(seeds) >= 0.8:
        # rolling seeds        
        #indexBestSeed = best.fitnessValues.index(max(best.fitnessValues))
        #seeds.pop(indexBestSeed)
        #new_seed = random.randint(0, 1000000)
        #seeds.append(new_seed)
        
    newSeeds = [random.randint(1, 10_000) for _ in range(1)]
    seeds = []
    seeds.extend(ancor)
    seeds.extend(newSeeds)

    #if g % 100 == 0:
    #    renderVideos(1,pop,g)
# Out:
# Per-seed rewards: [-23.001083374023438, -48.48313903808594, 6.592399597167969, -4.582283020019531, -5.043052673339844, 24.6920166015625]
# Min: -48.48313903808594
# Max: 24.6920166015625
# Landing rate: 0%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 14
#      10 fitnessProgess = []
#      11 for g in range(2000):
#      12
#      13     # 1. Multi-Seed Evaluation (C++ Geschwindigkeit!)
# ---> 14     pop.gymnasiumMultiSeed(env, dMax=50, maxSteps=1000, maxConsecutiveP=10,
#      15                            worstFitness=-500, seeds=seeds)
#      17     # 2. Pareto Objectives berechnen
#      18     #pop.calculateParetoObjectives(landingThreshold=100)
#      19
#      20     # 3. Pareto Tournament Selection
#      21     #pop.paretoTournamentSelection(N=2, E_reward=2, E_landing=2)
#      22     pop.tournamentSelection(N=2, E=2)
#
# ...

# %% [markdown]
# ## Inspecting the Best Individual
#
# Now we inspect the best individual:
# - Start node and its edges
# - Inner node types, functions, edges, and boundaries
#
# Because the Genetic Network Programming is **not** a Blackbox-Model

# %%
pop.individuals[-1].nCrossovers

# %%
pop.individuals[-1].fitness
print(f"Start Node: {pop.individuals[-1].startNode.edges}")
for node in pop.individuals[-1].innerNodes:
    if node.used == True:
        print(f"ID {node.id} Type: {node.type} | Function: {node.f} Edges: {node.edges} | Boundaries: {node.boundaries}")
    else:
        print(f"*ID {node.id} Type: {node.type} | Function: {node.f} Edges: {node.edges} | Boundaries: {node.boundaries}")

# %% [markdown]
# ## Own Individual

# %%
seed = 1
popSelfConstructed = fn.Population(
    seed=seed,
    ni=1,       # number of individuals
    jn=0,         # judgment nodes
    jnf=0,        # judgment node functions
    pn=12,         # processing nodes
    pnf=0,        # processing node functions
    fractalJudgment=False,
    nFeatureValues=[0,0,0,0,0,0,2,2]
)

# %%
popSelfConstructed.individuals[0].startNode.edges = [0]
nodes = [

    # landing module
    {"type":"J", "f":3, "edges":[2,1], "boundaries":[-10,-0.04, 10]}, # y velocity
    {"type":"P", "f":0, "edges":[3], "boundaries":[]}, # do nothing 
    {"type":"P", "f":2, "edges":[7], "boundaries":[]}, # fire main engine 

    # balance module 
    {"type":"J", "f":4, "edges":[2,4,0,5,2], "boundaries":[-6.2831855, -0.8 , -0.04, 0.04, 0.8, 6.2831855]}, # angular
    {"type":"P", "f":1, "edges":[11], "boundaries":[]}, # fire left
    {"type":"P", "f":3, "edges":[11], "boundaries":[]}, # fire right 

    # target module 
    {"type":"J", "f":0, "edges":[5,3,4], "boundaries":[-2.5, -0.1, 0.1, 2.5]}, # x achses

    # contact module 
    {"type":"J", "f":6, "edges":[8,9], "boundaries":[0,0.5,1]}, # left contact
    {"type":"J", "f":7, "edges":[6,9], "boundaries":[0,0.5,1]}, # right contact   
    {"type":"P", "f":0, "edges":[10], "boundaries":[]}, # do nothing 
    {"type":"P", "f":0, "edges":[9], "boundaries":[]}, # do nothing 

    # test 
    {"type":"P", "f":2, "edges":[3], "boundaries":[]}, # fire main engine 
    
]

for idx, node in enumerate(nodes):
    popSelfConstructed.individuals[0].innerNodes[idx].type = node["type"]
    popSelfConstructed.individuals[0].innerNodes[idx].f = node["f"]
    popSelfConstructed.individuals[0].innerNodes[idx].edges = node["edges"]
    popSelfConstructed.individuals[0].innerNodes[idx].boundaries = node["boundaries"]

# %%
env = gym.make("LunarLander-v3", continuous=False, gravity=-10.0,
               enable_wind=False, wind_power=0, turbulence_power=0)

popSelfConstructed.gymnasium(
    env,
    dMax = 10,
    maxSteps = 1500,
    maxConsecutiveP = 10,
    worstFitness = worstFitness,
    seed = seed
)

# %%
individual = popSelfConstructed.individuals[0]
plotNetwork(individual, filename = "lunarlander_solution_self_constructed.html")

# %% [markdown]
# We can also visualize the network in a plot, for example using the pyvis package.
#
# Colors:
#
# - Start node =
# - Processing nodes =
# - Judgment nodes =
#
# Tip: You can view the boundaries of an edge by hovering over it with your mouse.

# %%
individual = pop.individuals[pop.indicesElite[0]]
if len(individual.innerNodes) < 200:
    plotNetwork(individual, filename = "lunarlander_solution.html", justUsedNodes = False)

# %%
individual = pop.individuals[pop.indicesElite[0]]
plotNetwork(individual, filename = "lunarlander_solution_used.html", justUsedNodes = True, justUsedEdges = True)

# %% [markdown]
# ## Validation of the Best Individual
#
# The best individual is validated in a fresh environment.
# We compute the average fitness across multiple runs.

# %%
env = gym.make("LunarLander-v3")
# Keep only the best individual
popValidation = fn.Population(
    seed=seed,
    ni=1,       # number of individuals
    jn=1,         # judgment nodes
    jnf=8,        # judgment node functions
    pn=2,         # processing nodes
    pnf=4,        # processing node functions
    fractalJudgment=False,
    nFeatureValues=[0,0,0,0,0,0,2,2]
)
popValidation.individuals = copy.deepcopy([pop.individuals[pop.indicesElite[0]]])
validationResults = []

seeds = [random.randint(0, 10_000) for _ in range(100)]
for v in seeds:
    popValidation.gymnasium(
        env,
        dMax=20,
        maxSteps=1500,
        maxConsecutiveP=10,
        worstFitness=-500,
        seed=v
    )
    validationResults.append(popValidation.individuals[0].fitness)
    print(f"Fitness: {popValidation.individuals[0].fitness}")
print(f"Average Fitness of Validations: {statistics.mean(validationResults)}")

# %% [markdown]
# ## Rendering and Recording the Best Run
#
# Finally, we run the environment in `rgb_array` mode and use `RecordVideo`
# to save a video of the best individual playing CartPole. You can find the video in the nodebook folder "videos".

# %%
renderVideos(20, pop)
